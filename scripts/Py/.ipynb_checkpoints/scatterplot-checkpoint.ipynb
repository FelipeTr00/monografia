# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
penguins = sns.load_dataset("penguins")
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
import seaborn as sns
import pandas as pd

# Carregar o DataFrame original
df = pd.read_csv("/home/mrs/Documents/monografia/dados/dva_long.csv")
#df = pd.read_csv("/home/mrs/Documents/monografia/dados/scatterplot.csv")


# Selecionar as colunas desejadas
colunas_desejadas = ['SETOR_ECON', 'Governo' / 1000, 'Pessoal' / 1000, 'RCT' / 1000 , 'RCP' / 1000 ]

# Criar um novo DataFrame com apenas as colunas desejadas
df_plot = df[colunas_desejadas]

# Definir o tema e a paleta de cores
sns.set_theme(style="ticks")  # Ou qualquer outro tema de sua escolha


# Criar o pairplot com a paleta de cores e o parâmetro hue na parte superior

cores = {
    'Terciário': '#2ca02c',
    'Secundário': '#1f77b4',
    'Primário': '#ff7f0e',
    'Sem Setor Principal': '#9467bd'
}

ax = sns.pairplot(df_plot, hue='SETOR_ECON', diag_kind='kde', palette=cores)

# Ajustar o tamanho dos marcadores
mksize = 100
for lh in ax._legend.legendHandles:  # Itera sobre os marcadores na legenda
    lh.set_alpha(1)  # Define a opacidade para evitar que os marcadores fiquem transparentes
    lh._sizes = [mksize]  # Define o tamanho dos marcadores

# Mover a legenda para a parte superior
sns.move_legend(ax, "lower center", bbox_to_anchor=(0.5, 1), ncol=5, title=None, frameon=False)


#g.savefig("/home/mrs/Documents/monografia/plots/Scatter.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 10
#       5 df = pd.read_csv("/home/mrs/Documents/monografia/dados/dva_long.csv")
#       6 #df = pd.read_csv("/home/mrs/Documents/monografia/dados/scatterplot.csv")
#       7
#       8
#       9 # Selecionar as colunas desejadas
# ---> 10 colunas_desejadas = ['SETOR_ECON', 'Governo' / 1000, 'Pessoal' / 1000, 'RCT' / 1000 , 'RCP' / 1000 ]
#      12 # Criar um novo DataFrame com apenas as colunas desejadas
#      13 df_plot = df[colunas_desejadas]
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Carregar o DataFrame original
df = pd.read_csv("/home/mrs/Documents/monografia/dados/dva_long.csv")

# Selecionar as colunas desejadas
colunas_desejadas = ['SETOR_ECON', 'Governo', 'Pessoal']

# Criar um novo DataFrame com apenas as colunas desejadas
# df_plot = df[colunas_desejadas]
df_plot[['Governo', 'Pessoal']] = np.log(df_plot[['Governo', 'Pessoal']])

# Definir o tema e a paleta de cores
sns.set_theme(style="ticks")  # Ou qualquer outro tema de sua escolha

# Criar o pairplot com a paleta de cores e o parâmetro hue na parte superior

cores = {
    'Terciário': '#2ca02c',
    'Secundário': '#1f77b4',
    'Primário': '#ff7f0e',
    'Sem Setor Principal': '#9467bd'
}

ax = sns.pairplot(df_plot, hue='SETOR_ECON', diag_kind='kde', palette=cores)

# Ajustar o tamanho dos marcadores
mksize = 100
for lh in ax._legend.legendHandles:  # Itera sobre os marcadores na legenda
    lh.set_alpha(1)  # Define a opacidade para evitar que os marcadores fiquem transparentes
    lh._sizes = [mksize]  # Define o tamanho dos marcadores

# Mover a legenda para a lateral direita
sns.move_legend(ax, "center right", bbox_to_anchor=(1.0, 0.5), title=None, frameon=False)


plt.savefig("/home/mrs/Documents/monografia/plots/PessoalXGoverno.png")
# Out:
# /home/mrs/.local/lib/python3.11/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/mrs/.local/lib/python3.11/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# /tmp/ipykernel_6120/1408929823.py:32: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for lh in ax._legend.legendHandles:  # Itera sobre os marcadores na legenda
